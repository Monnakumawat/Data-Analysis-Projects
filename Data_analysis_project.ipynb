# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data2=pd.read_csv('NetFlix.csv')
data2
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Getting basic information about DataSet:-

# %% [markdown]
# # 1.head()

# %%
data2.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %% [markdown]
# # 2.tail()

# %%
data2.tail()
# Out:
#      show_id     type                      title             director  \
# 7782    s995  TV Show                 Blown Away                  NaN
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast  \
# 7782                                                NaN
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# ...

# %% [markdown]
# # 3.Shape

# %%
data2.shape                     #to show no. of rows and columns
# Out:
# (7787, 12)

# %% [markdown]
# #  4. Size

# %%
data2.size                                         # to show no. of total values in dataset
# Out:
# 93444

# %% [markdown]
# # 5. Columns

# %%
data2.columns                                                # to show each cloumns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %% [markdown]
# # 6. info()

# %%
data2.info()                                    #to show indexes,columns,data_types of each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %% [markdown]
# # 7. dtypes

# %%
data2.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int64
# genres          object
# description     object
# dtype: object

# %% [markdown]
# # task.1 Is there ant duplicate record in dataset? if yes, then remove the duplicates records

# %%
data2.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data2.shape
# Out:
# (7787, 12)

# %%
data2[data2.duplicated()]                    # to chexk row-wise
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description]
# Index: []

# %%
data2.drop_duplicates(inplace=True)   #inplace iss use for make changes permanent                                       # if we found any duplicates in dataset

# %% [markdown]
# # Task2. is there any null value present in any column? Show with Heat-map.

# %%
data2.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data2.isnull()                    #to show null values
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7782    False  False  False      True   True    False       False
# 7783    False  False  False      True  False    False       False
# 7784    False  False  False     False  False    False       False
# 7785    False  False  False     False  False    False       False
# 7786    False  False  False     False  False    False       False
#
#       release_year  rating  duration  genres  description
# 0            False   False     False   False        False
# ...

# %%
data2.isnull().sum()                                            #To show null value count
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
sns.heatmap(data2.isnull())                                        #using heat-map to show null value
# Out:
# <Axes: >

# %% [markdown]
# # Q1. For 'A Boy Name Flora A',what is the show id and who is the director in the show?

# %%
data2[data2['title'].isin(['A Boy Name Flora A'])]
# Out:
#     show_id     type               title director  \
# 590    s153  TV Show  A Boy Name Flora A      NaN
#
#                                                   cast country date_added  \
# 590  Crowd Lu, Tsai Chen-nan, Lotus Wang, Fan Chu-M...  Taiwan   1-Sep-17
#
#      release_year rating  duration  \
# 590          2017  TV-MA         1
#
#                                              genres  \
# 590  International TV Shows, TV Comedies, TV Dramas
#
#                                            description
# 590  A 28-year-old layabout begins to re-examine hi...

# %% [markdown]
# # str.contains()

# %%
data2[data2['title'].str.contains('A Boy Name Flora A')]
# Out:
#     show_id     type               title director  \
# 590    s153  TV Show  A Boy Name Flora A      NaN
#
#                                                   cast country date_added  \
# 590  Crowd Lu, Tsai Chen-nan, Lotus Wang, Fan Chu-M...  Taiwan   1-Sep-17
#
#      release_year rating  duration  \
# 590          2017  TV-MA         1
#
#                                              genres  \
# 590  International TV Shows, TV Comedies, TV Dramas
#
#                                            description
# 590  A 28-year-old layabout begins to re-examine hi...

# %% [markdown]
# # Q2. In which year highest number of TV shows & movies were released? Show with Bar Graph.

# %%
data2.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int64
# genres          object
# description     object
# dtype: object

# %% [markdown]
# # to_datetime

# %%
data2['release_year']=pd.to_datetime(data2['release_year'])

# %%
data2.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added                  release_year rating  duration  \
# ...

# %%
data2.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year    datetime64[ns]
# rating                  object
# duration                 int64
# genres                  object
# description             object
# dtype: object

# %%
data2['release_year'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Q3. How many T.V shows and Movies in the Dataset?Show wit Bar Graph.

# %% [markdown]
# # groupby()

# %%
data2.groupby('type').type.count()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %% [markdown]
# # countplot()

# %%
sns.countplot(x='type',data=data2)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# # Q4. Show only the titles of all TV Shows that were released in India and Japan only.

# %%
data2.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added                  release_year rating  duration  \
# ...

# %%
data2[ (data2['type']=='TV Show') & (data2['country']=='India')] ['title']
# Out:
# 354                                      Chhota Bheem
# 368                                         7 (Seven)
# 421     ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 461                                   Classic Legends
# 517                                   College Romance
#                             ...
# 7629                                           Betaal
# 7643                     21 Sarfarosh: Saragarhi 1897
# 7655                                      Bh Se Bhade
# 7656                               Bhaag Beanie Bhaag
# 7657                                   Bhaage Re Mann
# Name: title, Length: 71, dtype: object

# %%
data2[ (data2['type']=='TV Show') & (data2['country']=='Japan')] ['title']
# Out:
# 10                             BNA
# 186     Cagaster of an Insect Cage
# 239              Cardcaptor Sakura
# 253               CAROLE & TUESDAY
# 262                    Case Closed
#                    ...
# 7647        Beyblade: Metal Fusion
# 7730                  Black Butler
# 7758     Blazing Transfer Students
# 7759                        Bleach
# 7783                 Blue Exorcist
# Name: title, Length: 157, dtype: object

# %% [markdown]
# # Q6. show top 10 directors,who gave the highest number of TV shows and movies to Netflix?

# %% [markdown]
# # value_counts()

# %%
data2.head(2)
# Out:
#   show_id     type title      director  \
# 0      s1  TV Show    3%           NaN
# 1     s10    Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#                    release_year rating  duration  \
# 0 1970-01-01 00:00:00.000002020  TV-MA         4
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...

# %%
data2['director'].value_counts()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
#                           ..
# Mariano Baez               1
# Ravikanth Perepu           1
# Santram Varma              1
# Oliver Blackburn           1
# Woody Allen                1
# Name: director, Length: 4049, dtype: int64

# %% [markdown]
# # Show all the records ,where "Type is movie and genres is comedies" or "Country is India".

# %% [markdown]
# # filtering (And ,Or operator)

# %%
data2.head(2)
# Out:
#   show_id     type title      director  \
# 0      s1  TV Show    3%           NaN
# 1     s10    Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#                    release_year rating  duration  \
# 0 1970-01-01 00:00:00.000002020  TV-MA         4
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...

# %%
data2[ (data2['type']=='Movie')&(data2['genres']=='Comedies') ]
# Out:
#      show_id   type                                      title  \
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 121    s1107  Movie            Bring It On: Worldwide Showdown
# 258    s1230  Movie                           Casa de mi Padre
# 411    s1369  Movie                         Christmas Survival
# 460    s1412  Movie                                 Class Rank
# ...      ...    ...                                        ...
# 7561    s796  Movie                                Bebe's Kids
# 7621     s85  Movie                                  21 & Over
# 7638    s865  Movie               Between Two Ferns: The Movie
# 7679    s901  Movie                                   Big Bear
# 7680    s902  Movie                                  Big Daddy
#
#                     director  \
# 3               Lev L. Spiro
# 121           Robert Adetuyi
# 258            Matt Piedmont
# 411            James Dearden
# 460              Eric Stoltz
# ...

# %%
data2[ (data2['type']=='Movie')&(data2['genres']=='Comedies')|(data2['country']=='India') ]
# Out:
#      show_id   type                                      title  \
# 1        s10  Movie                                       1920
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 8      s1005  Movie                               BluffMaster!
# 13      s101  Movie                                   3 Idiots
# 21     s1017  Movie                                      Bobby
# ...      ...    ...                                        ...
# 7714    s933  Movie                                   Bioscope
# 7726    s944  Movie                                Bittoo Boss
# 7727    s945  Movie                                      Black
# 7734    s951  Movie                               Black Friday
# 7774    s988  Movie                                Blood Money
#
#                                                director  \
# 1                                          Vikram Bhatt
# 3                                          Lev L. Spiro
# ...

# %% [markdown]
# # In how many Movies/Shows,Aamir Khan was cast?

# %%
data2.head(2)
# Out:
#   show_id     type title      director  \
# 0      s1  TV Show    3%           NaN
# 1     s10    Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#                    release_year rating  duration  \
# 0 1970-01-01 00:00:00.000002020  TV-MA         4
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...

# %% [markdown]
# # filtering

# %%
data2[data2['cast']=='Aamir Khan']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description]
# Index: []

# %% [markdown]
# # str.contains()

# %%
data2[data2['cast'].str.contains('Aamir Khan')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data2[data2['cast'].str.contains('Aamir Khan')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     133         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %% [markdown]
# # Creating new Data_frame

# %%
new_data=data2.dropna()

# %%
new_data.head(2)
# Out:
#   show_id   type       title        director  \
# 1     s10  Movie        1920    Vikram Bhatt
# 2    s100  Movie  3 Heroines  Iman Brotoseno
#
#                                                 cast    country date_added  \
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...      India  15-Dec-17
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...  Indonesia   5-Jan-19
#
#                    release_year rating  duration  \
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
# 2 1970-01-01 00:00:00.000002016  TV-PG       124
#
#                                            genres  \
# 1  Horror Movies, International Movies, Thrillers
# 2     Dramas, International Movies, Sports Movies
#
#                                          description
# 1  An architect and his wife move into a castle t...
# 2  Three Indonesian women break records by becomi...

# %%
new_data[new_data['cast'].str.contains('Aamir Khan')]
# Out:
#      show_id   type                        title                 director  \
# 13      s101  Movie                     3 Idiots          Rajkumar Hirani
# 663    s1596  Movie                       Dangal            Nitesh Tiwari
# 824    s1740  Movie  Dhobi Ghat (Mumbai Diaries)                Kiran Rao
# 842    s1757  Movie                          Dil              Indra Kumar
# 843    s1758  Movie               Dil Chahta Hai            Farhan Akhtar
# 844    s1759  Movie              Dil Dhadakne Do              Zoya Akhtar
# 2804   s3522  Movie                       Lagaan       Ashutosh Gowariker
# 3166   s3849  Movie        Madness in the Desert         Satyajit Bhatkal
# 3238   s3913  Movie                         Mann              Indra Kumar
# 4304   s4873  Movie                           PK          Rajkumar Hirani
# 4532   s5078  Movie              Raja Hindustani         Dharmesh Darshan
# 4534    s508  Movie              Andaz Apna Apna        Rajkumar Santoshi
# ...

# %% [markdown]
# # Q8. What are the different rating defined by Netflix?

# %% [markdown]
# # nunique()

# %%
data2.head(2)
# Out:
#   show_id     type title      director  \
# 0      s1  TV Show    3%           NaN
# 1     s10    Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#                    release_year rating  duration  \
# 0 1970-01-01 00:00:00.000002020  TV-MA         4
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...

# %%
data2['rating'].nunique()
# Out:
# 14

# %% [markdown]
# # unique

# %%
data2['rating'].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %% [markdown]
# # how many Movies got the 'TV_PG' rating ,in India?

# %%
data2.head(2)
# Out:
#   show_id     type title      director  \
# 0      s1  TV Show    3%           NaN
# 1     s10    Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#                    release_year rating  duration  \
# 0 1970-01-01 00:00:00.000002020  TV-MA         4
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...

# %%
data2[ (data2['type']=='Movie')&(data2['rating']=='TV-PG') ]
# Out:
#      show_id   type                                              title  \
# 2       s100  Movie                                         3 Heroines
# 24      s102  Movie                                  3 Seconds Divorce
# 29     s1024  Movie                                              Bogda
# 89     s1079  Movie  Brave Blue World: Racing to Solve Our Water Cr...
# 104    s1092  Movie                                  Breaking the Bank
# ...      ...    ...                                                ...
# 7706    s926  Movie                              Bill Nye: Science Guy
# 7707    s927  Movie                                              Billu
# 7709    s929  Movie             Billy Graham: An Extraordinary Journey
# 7739    s956  Movie                               Black Man White Skin
# 7760    s975  Movie                    Bleach The Movie: Fade to Black
#
#                              director  \
# 2                      Iman Brotoseno
# ...

# %%
data2[ (data2['type']=='Movie')&(data2['rating']=='TV-PG') &(data2['country']=='India')]
# Out:
#      show_id   type                              title  \
# 29     s1024  Movie                              Bogda
# 231    s1206  Movie                         Cappuccino
# 285    s1255  Movie                      Celluloid Man
# 289    s1259  Movie                   Chaar Sahibzaade
# 291    s1260  Movie              Chadi Jawani Budhe Nu
# ...      ...    ...                                ...
# 7456    s771  Movie                           Bawarchi
# 7554     s79  Movie                           2 States
# 7640    s867  Movie                            Bewafaa
# 7660    s885  Movie  Bhai: Vyakti Ki Valli - Uttarardh
# 7707    s927  Movie                              Billu
#
#                        director  \
# 29                Nisheeta Keni
# 231                     Noushad
# 285   Shivendra Singh Dungarpur
# 289                Harry Baweja
# 291                         NaN
# ...                         ...
# 7456       Hrishikesh Mukherjee
# 7554            Abhishek Varman
# ...

# %% [markdown]
# # Which individual country has the highest No. of Tv Shows?

# %%
data2.head(2)
# Out:
#   show_id     type title      director  \
# 0      s1  TV Show    3%           NaN
# 1     s10    Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#                    release_year rating  duration  \
# 0 1970-01-01 00:00:00.000002020  TV-MA         4
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...

# %%
tv_data=data2[data2['type']=='TV Show']

# %%
tv_data.head(2)
# Out:
#   show_id     type           title director  \
# 0      s1  TV Show              3%      NaN
# 4   s1001  TV Show  Blue Planet II      NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 4                                 David Attenborough  United Kingdom
#
#   date_added                  release_year rating  duration  \
# 0  14-Aug-20 1970-01-01 00:00:00.000002020  TV-MA         4
# 4   3-Dec-18 1970-01-01 00:00:00.000002017   TV-G         1
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 4  British TV Shows, Docuseries, Science & Nature TV
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 4  This sequel to the award-winning nature series...

# %%
tv_data.country.value_counts()
# Out:
# United States                                  705
# United Kingdom                                 204
# Japan                                          157
# South Korea                                    147
# India                                           71
#                                               ...
# Uruguay, Germany                                 1
# China, United Kingdom                            1
# South Korea, France                              1
# Norway, United States                            1
# Saudi Arabia, Syria, Egypt, Lebanon, Kuwait      1
# Name: country, Length: 183, dtype: int64

# %%
tv_data.country.value_counts().head(1)
# Out:
# United States    705
# Name: country, dtype: int64

# %% [markdown]
# # How can we sort dataset by Year?

# %%
data2.head(2)
# Out:
#   show_id     type title      director  \
# 0      s1  TV Show    3%           NaN
# 1     s10    Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  14-Aug-20
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#                    release_year rating  duration  \
# 0 1970-01-01 00:00:00.000002020  TV-MA         4
# 1 1970-01-01 00:00:00.000002008  TV-MA       143
#
#                                               genres  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  An architect and his wife move into a castle t...

# %%
data2.sort_values(by='release_year')
# Out:
#      show_id     type                                              title  \
# 4298   s4868  TV Show                  Pioneers: First Women Filmmakers*
# 4402   s4961    Movie                                     Prelude to War
# 5688   s6118    Movie                               The Battle of Midway
# 7423   s7680    Movie                    WWII: Report from the Aleutians
# 7353   s7617    Movie                 Why We Fight: The Battle of Russia
# ...      ...      ...                                                ...
# 4562   s5104    Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 1937   s2742  TV Show                                              Hilda
# 6087   s6478  TV Show                               The Idhun Chronicles
# 7384   s7645    Movie                                           Wish You
# 3528   s4174  TV Show                                            Monarca
#
#                              director  \
# 4298                              NaN
# ...
